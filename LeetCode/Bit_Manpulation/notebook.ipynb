# %%
for _ in range(10) :
    count: dict[str, int] = {}
    count.get("joti",0)

# %%
def matchCount(a: str, b: str) -> int:
    count = 0
    for x, y in zip(a, b):
        if x == y:
            count += 1
    return count

def guess_word(words: list, word: Master):
    count:dict[str, int] = {}

    for a in range(10) :
        for i in words :
            for j in words :
                if matchCount(i, j) == 0 :
                    continue
                count[i] = count.get(words[i],0)+1
        candidate = words[0]
        Min = count.get(candidate, 0)
        for i in words :
            for j in count :
                if i == j :
                    candidate = count.get(j,0)

        candidate = Master.guess(candidate)
        for a, b in zip(candidate, words) :
            if matchCount(a,b) ==

# %%
len(count)

# %%
count.get("joti",0) + 1

# %%
class Solution:
    def singleNumber(self, nums: list[int]) -> int:
        if len(nums) == 1 :
            return nums[0]
        for i in nums :
            single_number = True 
            for j in nums :
                if (i != j and nums[i] == nums[j]) :
                    single_number = False
            if single_number == True :
                return nums[i]

# %%
def singleNumber(nums: list[int]) -> int:
    if len(nums) == 1 :
        return nums[0]
    for i in range(len(nums)) :
        single_number = True 
        print(f"outer iteration i = {i}")
        for j in range(len(nums)) :
            print(f"j = {j}")
            if (i != j and nums[i] == nums[j]) :
                print(f"inner iteration i {i} and {j}")
                single_number = False
        if single_number == True :
            return nums[i]

nums = [4,1,2,1,2]
result = singleNumber(nums=nums)
print(result)

# %% [markdown]
# ## Bit Manipulation

# %% [markdown]
# #### single number

# %%
class Solution :
    def single_number(self, nums:list[int]) :
        map = dict[int , int]
        inc = 0
        for i in range(len(nums)) :
            map[i] = map[nums[i]]

# %%
nums = [4,1,2,1,2]
map:dict[int , int] = {}
inc = 0
for i in range(len(nums)) :
    map[i] = nums[i]

map.

# %%
len(map)

# %%
map.items()

# %%
nums = [4,1,2,1,2]
count:dict[int,int] = {}
for num in nums :
    count[num] = count.get(num,0)

# %%
count

# %%
count.get(1)

# %% [markdown]
# ### Count total Bit

# %%
def hammingWeight(n: int) -> int:
    total_bit = []
    while(n >= 1) :
        if(n % 2 != 0):
            n = n - 1
            n = n / 2
            total_bit.append(1)
        else :
            n = n / 2
            #total_bit.append(0)
    # print(len(total_bit))
    # print(total_bit)
    bit = len(total_bit)
    return bit
hammingWeight(128)

# %%
25%2

# %%
50%2

# %%
a2 = 50/2

# %%
25%2

# %%
class Solution:
    def hammingWeight(self, n: int) -> int:
        count = 0
        n &= 0xFFFFFFFF
        for _ in range(32):
            if (n & 1) == 1:
                count += 1
            n >>= 1
        return count

# %%
n = 5
n &= 0xFFFFFFFF
print(n)

# %%
def countBits(n: int) -> list[int]:

    arr = []
    num = n
    #n &= 0xFFFFFFFF
    for i in range(n+1) :
        count = 0
        i &= 0xFFFFFFFF
        for _ in range(30) :
            if(i & 1) == 1 :
                count += 1
            i >>= 1
        arr.append(count)
    return arr

# %%
countBits(5)

# %%
21/2

# %%
21//2

# %%
(5 >> 1) + ( 5 & 1)

# %%
def reverseBits(n: int) -> int:
    arr = []
    
    while(n >= 1) :
        if(n/2 == 0 ):
            n = n / 2
            arr.append(0)
        else :
            n//2
            arr.append(1)

# %%
reverseBits(43261596)

# %%
def reverseBits1(n:int) :
    arr = []
    newarr = []
    n &= 0xFFFFFFFF
    for _ in range(32) :
        if ( n & 1) == 1 :
            arr.append(1)
        else:
            arr.append(0)
        n >>= 1
    for i in range(-1,-30,-1) :
        temp = arr[i]
    

    #print(arr)
    print(arr)
    return arr

# %%
arr1 = reverseBits1(43261596)

# %%
for i in range(-1, -30, -1) :
    print(i)

# %%
for i in range(4):
    print(i)

# %%
a = 5
a &= 0xFFFFFFFF
range(a)

# %%
def reverseBits1(n:int) :
    arr = []
    newarr = []
    n &= 0xFFFFFFFF
    for _ in range(3) :
        temp = n & 1
        temp1 = 1 & n
        print(temp)
        print(temp1)

# %%
reverseBits1(4)

# %%
for i in range(5) :
    temp = i
    print(temp)

# %%
a1 = 0

# %%
a1>>=1

# %%
def func(n:int) ->int :
    n &= 0XFFFFFFFF
    result = 0
    result &= 0xFFFFFFFF
    for _ in range(32) :
    
        result <<=1
        if (n&1) == 1:
            result |= 1
        n>>=1
    return result

# %%
func(43261596)

# %% [markdown]
# ### 201. Bitwise AND of Numbers Range

# %%
class Solution:
    def rangeBitwiseAnd(self, left: int, right: int) -> int:
        #result = 1
        for i in range(left, right + 1) :
            left = left & i
            #result = left
        return left

# %%
sol1 = Solution()

# %%
sol1.rangeBitwiseAnd(5,7)
# Out:
# 4

# %%
1-1

# %%
0-0

# %%
5 & 4 & 7
# Out:
# 4

# %%
for i in range(1, 2) :
    print(i)
# Out:
# 1

# %%
1 & 1
# Out:
# 1
