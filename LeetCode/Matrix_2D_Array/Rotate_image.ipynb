# %%
matrix = [[5,1,9,11],[2,4,8,10],[13,3,6,7],[15,14,12,16]]

# %%
int(len(matrix) / 2)
# Out:
# 2

# %%
class Solution:
    def rotate(self, matrix: list[list[int]]) -> None:
        """
        Do not return anything, modify matrix in-place instead.
        """
        bottom = len(matrix) - 1
        right = len(matrix[0]) - 1
        left = 0
        top = 0
        len_matrix = len(matrix) - 1
        redlen = 0
        for i in range(int(len(matrix)/2)) :
        #for i in range(bottom, top) :
            
            for j in range(len(matrix) - redlen - 1) :
                temp1 = matrix[i][j + i]
                matrix[i][j + i] = matrix[len_matrix - j - i][i]
                #bottom -= 1

            #for i in range(left, right) :
                temp2 = matrix[j + i][len_matrix - i]
                matrix[j + i][len_matrix - i] = temp1
                #left += 1

            #for i in range(top, bottom) :
                temp3 = matrix[len_matrix- i][len_matrix - j - i]
                matrix[len_matrix - i][len_matrix - j - i] = temp2
                #top -= 1

            #for i in range(right, left) :
                matrix[len_matrix - j - i][i] = temp3
                #right -= 1
            redlen +=2
        print(matrix)

# %%
s = Solution()

# %%
matrix = [[5,1,9,11],[2,4,8,10],[13,3,6,7],[15,14,12,16]]

# %%
s.rotate(matrix)
# Out:
# [[15, 13, 2, 5], [14, 3, 4, 1], [12, 6, 8, 9], [16, 7, 10, 11]]

# %%
class Solution:
    def rotate(self, matrix: list[list[int]]) -> None:
        """
        Do not return anything, modify matrix in-place instead.
        """
        len_matrix = len(matrix) - 1
        redlen = 0
        for i in range(int(len(matrix)/2)) :
            
            for j in range(len(matrix) - redlen - 1) :
                temp1 = matrix[i][j + i]
                matrix[i][j + i] = matrix[len_matrix - j - i][i]

                temp2 = matrix[j + i][len_matrix - i]
                matrix[j + i][len_matrix - i] = temp1
    
                temp3 = matrix[len_matrix- i][len_matrix - j - i]
                matrix[len_matrix - i][len_matrix - j - i] = temp2
           

         
                matrix[len_matrix - j - i][i] = temp3
            redlen +=2
        print(matrix)

# %%
s = Solution()

# %%
matrix = [[5,1,9],[2,4,8],[13,3,6]]

# %%
s.rotate(matrix)
# Out:
# [[13, 2, 5], [3, 4, 1], [6, 8, 9]]
