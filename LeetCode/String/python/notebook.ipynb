# %%
for _ in range(10) :
    count: dict[str, int] = {""}
    count.get("joti",0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 3
#       1 for _ in range(10) :
#       2     count: dict[str, int] = {""}
# ----> 3     count.get("joti",0)
#
# AttributeError: 'set' object has no attribute 'get'

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 count
#
# NameError: name 'count' is not defined

# %%
len(count)
# Out:
# 1

# %%
count.get("joti",0) + 1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 count.get("joti",0) + 1
#
# AttributeError: 'set' object has no attribute 'get'
